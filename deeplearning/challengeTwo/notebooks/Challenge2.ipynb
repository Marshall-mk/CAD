# %%
# !pip install hydra-core

# %%
from google.colab import drive
drive.mount('/content/drive',True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CAD/deeplearning/challengeTwo/src
# !python train.py
# Out:
# /content/drive/.shortcut-targets-by-id/1vc4G6FtyYiOQNj76VxDXMjSYyfkoDd6t/CAD/deeplearning/challengeTwo/src
# cuda:0
# DataSet Sizes: {'train': 5086, 'val': 1270}
# Class Names: ['bcc', 'mel', 'scc']
# Class Weights: tensor([0.1421, 0.1044, 0.7534], device='cuda:0')
# Data Loaded
# Multiple Models Training Started
# Training convit_small
# [2024-10-20 21:10:52,641][timm.models._builder][INFO] - Loading pretrained weights from Hugging Face hub (timm/convit_small.fb_in1k)
# [2024-10-20 21:10:52,761][timm.models._hub][INFO] - [timm/convit_small.fb_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Training Started
# Epoch 1/25
# ...
# train Loss: 0.0631 Acc: 0.5991 Kappa: 0.3691
# val Loss: 0.0555 Acc: 0.6575 Kappa: 0.4613
# [2024-10-20 21:11:55,248][root][INFO] - Checkpoint 1 saved !
#               precision    recall  f1-score   support
#
#          bcc       0.66      0.84      0.74       498
# ...
