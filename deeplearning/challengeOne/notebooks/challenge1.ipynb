# %%
# !pip install hydra-core

# %%
from google.colab import drive
drive.mount('/content/drive',True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/CAD/deeplearning/challengeOne/src
# !python train.py
# Out:
# /content/drive/.shortcut-targets-by-id/1vc4G6FtyYiOQNj76VxDXMjSYyfkoDd6t/CAD/deeplearning/challengeOne/src
# cuda:0
# DataSet Sizes: {'train': 15195, 'val': 3796}
# Class Names: ['nevus', 'others']
# Class Weights: tensor([0.4916, 0.5084], device='cuda:0')
# Data Loaded
# Multiple Models Training Started
# Training mobilenet
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100% 13.6M/13.6M [00:00<00:00, 196MB/s]
# Training Started
# Epoch 1/25
# ...
# train Loss: 0.1168 Acc: 0.7907, Kappa: 0.5813
# val Loss: 0.1018 Acc: 0.8288, Kappa: 0.6564
# [2024-10-20 21:10:35,887][root][INFO] - Checkpoint 1 saved !
# [2024-10-20 21:10:35,897][root][INFO] - Epoch 1  Accuracy: 0.8288 Precision: 0.8947 Recall: 0.7383 F1-Score: 0.8090 Loss: 0.1018 TP: 1377 TN: 1769 FP: 162 FN: 488, Kappa: 0.6564
# Confusion matrix, without normalization
# [[1769  162]
#  [ 488 1377]]
# Figure(800x600)
# Epoch 2/25
# ...
